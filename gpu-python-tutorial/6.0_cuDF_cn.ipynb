# %% [markdown]
# # cuDF
#
# 现在让我们转向一些更高级的 API，从 [cuDF](https://github.com/rapidsai/cudf) 开始。与 `pandas` 类似，`cudf` 库是一个用于处理表格数据集的数据框架包。
#
# 数据被加载到 GPU 上，所有操作都使用 GPU 计算执行，但 `cudf` 的 API 对于 `pandas` 用户来说应该非常熟悉。

# %%
# !pwd
# Out:
# /data/workdir/accelerated-computing-hub/gpu-python-tutorial

# %%
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# fatal: destination path 'rapidsai-csp-utils' already exists and is not an empty directory.
# Installing RAPIDS remaining 25.08 libraries
# /bin/sh: line 1: uv: command not found
#
#         ***********************************************************************
#         The pip install of RAPIDS is complete.
#
#         Please do not run any further installation from the conda based installation methods, as they may cause issues!
#
#         Please ensure that you're pulling from the git repo to remain updated with the latest working install scripts.
#
#         Troubleshooting:
#             - If there is an installation failure, please check back on RAPIDSAI owned templates/notebooks to see how to update your personal files.
#             - If an installation failure persists when using the latest script, please make an issue on https://github.com/rapidsai-community/rapidsai-csp-utils
#         ***********************************************************************

# %%
import cudf

# %% [markdown]
# ## 数据加载

# %% [markdown]
# 在本教程中，我们在 `data/` 目录下存储了一些数据。这些数据大部分都太小，无法真正从 GPU 加速中受益，但让我们还是来探索一下。

# %%
import pandas as pd

# %%
df = pd.read_csv("/data/workdir/accelerated-computing-hub/gpu-python-tutorial/data/pageviews_small.csv", sep=" ")
df.head()
# Out:
#    en.m                   Article_51  1  0
# 0    ja                       エレファモン  1  0
# 1   ang                Flocc:Scīrung  1  0
# 2    en  Panorama_(La_Dispute_album)  1  0
# 3  fa.m                  جاشوا_جکسون  1  0
# 4  fa.m                 خانواده_کندی  2  0

# %%
pageviews = cudf.read_csv("/data/workdir/accelerated-computing-hub/gpu-python-tutorial/data/pageviews_small.csv", sep=" ")
pageviews.head()
# Out:
#    en.m                   Article_51  1  0
# 0    ja                       エレファモン  1  0
# 1   ang                Flocc:Scīrung  1  0
# 2    en  Panorama_(La_Dispute_album)  1  0
# 3  fa.m                  جاشوا_جکسون  1  0
# 4  fa.m                 خانواده_کندی  2  0

# %% [markdown]
# 这个 `pageviews.csv` 文件包含了来自各种语言的维基百科的超过 `1M` 条页面浏览量记录。
#
# 让我们重命名列并删除未使用的 `x` 列。

# %%
pageviews.columns = ['project', 'page', 'requests', 'x']

pageviews = pageviews.drop('x', axis=1)

pageviews
# Out:
#         project                         page  requests
# 0            ja                       エレファモン         1
# 1           ang                Flocc:Scīrung         1
# 2            en  Panorama_(La_Dispute_album)         1
# 3          fa.m                  جاشوا_جکسون         1
# 4          fa.m                 خانواده_کندی         2
# ...         ...                          ...       ...
# 1118994      ja                        STUTS         2
# 1118995    ml.m                   മാർച്ച്_18         3
# 1118996    es.m        Pablo_Sánchez_Velarde         1
# 1118997      ar         مترو_الجزائر_العاصمة         1
# 1118998      pt                Fabián_Chávez         1
#
# [1118999 rows x 3 columns]

# %% [markdown]
# 接下来，让我们统计这个数据集中有多少条英文记录。

# %%
print(pageviews[pageviews.project == 'en'].count())
# Out:
# project     196882
# page        196881
# requests    196882
# dtype: int64

# %% [markdown]
# 然后让我们执行一个分组操作，按语言统计所有页面。

# %%
grouped_pageviews = pageviews.groupby('project').count().reset_index()
grouped_pageviews
# Out:
#      project  page  requests
# 0     hu.m.b    21        21
# 1     en.voy   564       564
# 2       ba.m     3         3
# 3       es.v    30        30
# 4       tr.b    13        13
# ...      ...   ...       ...
# 1347      pi    12        12
# 1348    pt.q    23        23
# 1349  id.m.d   393       393
# 1350   dty.m     1         1
# 1351  pl.m.n    28        28
#
# [1352 rows x 3 columns]

# %% [markdown]
# 最后，让我们查看英语、法语、中文和波兰语的结果。

# %%
print(grouped_pageviews[grouped_pageviews.project.isin(['en', 'fr', 'zh', 'pl'])])
# Out:
#      project    page  requests
# 257       en  196881    196882
# 781       zh   17577     17577
# 940       pl   11931     11931
# 1077      fr   33915     33915

# %% [markdown]
# 如果你之前使用过 `pandas`，那么所有这些语法对你来说应该非常熟悉。就像 `cupy` 实现了 `numpy` API 的大部分功能一样，`cudf` 实现了 `pandas` API 的大部分功能。
#
# 唯一的区别是，我们所有的过滤和分组操作都在 GPU 上执行，而不是在 CPU 上，从而获得更好的性能。

# %% [markdown]
# ### 字符串
#
# GPU 历来以数值计算而闻名，并没有被用于处理更复杂的对象。使用 cuDF，字符串操作也可以通过专门的内核进行加速。
#
# 这意味着像大写字符串这样的操作可以在 GPU 上并行化。

# %%
pageviews[pageviews.project == 'en'].page.str.upper()
# Out:
# 2                    PANORAMA_(LA_DISPUTE_ALBUM)
# 9                                 OPERATING_COST
# 19         RICHARD_BARLOW_(INTELLIGENCE_ANALYST)
# 27                 ST_VINCENT_AND_THE_GRENADINES
# 28                                     IAN_MCKEE
#                            ...
# 1118958                               DEVIL_GIRL
# 1118969           PHILOSOPHERS_LEGACY_(HEIRLOOM)
# 1118973                               KINGS_HILL
# 1118986                   TIONNE_"T-BOZ"_WATKINS
# 1118989                             ANTINEUTRINO
# Name: page, Length: 196882, dtype: object

# %%
pageviews_en = pageviews[pageviews.project == 'en']
print(pageviews_en.page.str.upper().head())
# Out:
# 2               PANORAMA_(LA_DISPUTE_ALBUM)
# 9                            OPERATING_COST
# 19    RICHARD_BARLOW_(INTELLIGENCE_ANALYST)
# 27            ST_VINCENT_AND_THE_GRENADINES
# 28                                IAN_MCKEE
# Name: page, dtype: object

# %% [markdown]
# ### 用户自定义函数（UDF）
#
# cuDF 还支持用户自定义函数（UDF），可以在 GPU 上并行地映射到 Series 或 DataFrame 上。
#
# UDF 可以定义为接受单个值的纯 Python 函数。当我们调用 `.apply()` 时，这些函数将在运行时由 Numba 编译成可以在 GPU 上运行的代码。

# %%
def udf(x):
    if x < 5:
        return 0
    return x

# %%
pageviews.requests = pageviews.requests.apply(udf)
# Out:
# ---------------------------------------------------------------------------
# CudaAPIError                              Traceback (most recent call last)
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:2817, in CtypesLinker.add_file(self, path, kind)
#    2816 try:
# -> 2817     driver.cuLinkAddFile(self.handle, kind, pathbuf, 0, None, None)
#    2818 except CudaAPIError as e:
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:304, in Driver._ctypes_wrap_fn.<locals>.safe_cuda_api_call(*args)
#     303 retcode = libfn(*args)
# --> 304 self._check_ctypes_error(fname, retcode)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:372, in Driver._check_ctypes_error(self, fname, retcode)
#     371     self._detect_fork()
# --> 372 raise CudaAPIError(retcode, msg)
#
# CudaAPIError: [222] Call to cuLinkAddFile results in CUDA_ERROR_UNSUPPORTED_PTX_VERSION
#
# During handling of the above exception, another exception occurred:
#
# LinkerError                               Traceback (most recent call last)
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/indexed_frame.py:3515, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3514     kr = kernel_class(self, func, args)
# -> 3515     kernel, retty = kr.get_kernel()
#    3516 except Exception as e:
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/udf/udf_kernel_base.py:167, in ApplyKernelBase.get_kernel(self)
#     166 def get_kernel(self):
# --> 167     return self._compile_or_get_kernel()
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/udf/udf_kernel_base.py:184, in ApplyKernelBase._compile_or_get_kernel(self)
#     182     return kernel, masked_or_scalar
# --> 184 kernel, scalar_return_type = self.compile_kernel()
#     186 np_return_type = (
#     187     numpy_support.as_dtype(scalar_return_type)
#     188     if scalar_return_type.is_internal
#     189     else scalar_return_type.np_dtype
#     190 )
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/udf/udf_kernel_base.py:145, in ApplyKernelBase.compile_kernel(self)
#     144 kernel_string = self._get_kernel_string()
# --> 145 kernel = self.compile_kernel_string(
#     146     kernel_string, nrt=capture_nrt_usage.use_nrt
#     147 )
#     149 return kernel, return_type
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/udf/udf_kernel_base.py:159, in ApplyKernelBase.compile_kernel_string(self, kernel_string, nrt)
#     158 with ctx:
# --> 159     kernel = cuda.jit(
#     160         self.sig,
#     161         link=[UDF_SHIM_FILE],
#     162         extensions=[str_view_arg_handler],
#     163     )(_kernel)
#     164 return kernel
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/decorators.py:133, in jit.<locals>._jit(func)
#     132     else:
# --> 133         disp.compile(argtypes)
#     135 disp._specialized = specialized
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/dispatcher.py:934, in CUDADispatcher.compile(self, sig)
#     933 # We call bind to force codegen, so that there is a cubin to cache
# --> 934 kernel.bind()
#     935 self._cache.save_overload(sig, kernel)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/dispatcher.py:197, in _Kernel.bind(self)
#     194 """
#     195 Force binding to current CUDA context
#     196 """
# --> 197 self._codelibrary.get_cufunc()
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/codegen.py:214, in CUDACodeLibrary.get_cufunc(self)
#     212     return cufunc
# --> 214 cubin = self.get_cubin(cc=device.compute_capability)
#     215 module = ctx.create_module_image(cubin)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/codegen.py:191, in CUDACodeLibrary.get_cubin(self, cc)
#     190 for path in self._linking_files:
# --> 191     linker.add_file_guess_ext(path)
#     192 if self.needs_cudadevrt:
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:2641, in Linker.add_file_guess_ext(self, path)
#    2639     raise RuntimeError("Don't know how to link file with extension "
#    2640                        f".{ext}")
# -> 2641 self.add_file(path, kind)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:2823, in CtypesLinker.add_file(self, path, kind)
#    2822     msg = "%s\n%s" % (e, self.error_log)
# -> 2823 raise LinkerError(msg)
#
# LinkerError: [222] Call to cuLinkAddFile results in CUDA_ERROR_UNSUPPORTED_PTX_VERSION
# ptxas application ptx input, line 9; fatal   : Unsupported .version 8.8; current version is '8.6'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pageviews.requests = pageviews.requests.apply(udf)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/series.py:2566, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    2563 elif by_row != "compat":
#    2564     raise NotImplementedError("by_row is currently not supported.")
# -> 2566 result = self._apply(func, SeriesApplyKernel, *args, **kwargs)
#    2567 result.name = self.name
#    2568 return result
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/nvidia/lib/python3.11/site-packages/cudf/core/indexed_frame.py:3517, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3515     kernel, retty = kr.get_kernel()
#    3516 except Exception as e:
# -> 3517     raise ValueError(
#    3518         "user defined function compilation failed."
#    3519     ) from e
#    3521 # Mask and data column preallocated
#    3522 ans_col = _return_arr_from_dtype(retty, len(self))
#
# ValueError: user defined function compilation failed.

# %%
pageviews.requests
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#           ..
# 1118994    2
# 1118995    3
# 1118996    1
# 1118997    1
# 1118998    1
# Name: requests, Length: 1118999, dtype: int64

# %% [markdown]
# 也可以直接使用 Numba 编写内核，这些内核接受指向输入列和输出列的指针以及额外的参数。然后，内核可以使用 `cuda.grid`，就像我们在第 2/3 章中所做的那样，来获取要操作的索引。
#
# 然后我们使用 `.forall()` 将我们的内核映射到列上。

# %%
pageviews['mul_requests'] = 0.0

# %%
from numba import cuda
from numba import config as numba_config
numba_config.CUDA_ENABLE_PYNVJITLINK = True

# %%
@cuda.jit
def multiply(in_col, out_col, multiplier):
    i = cuda.grid(1)
    if i < in_col.size: # boundary guard
        out_col[i] = in_col[i] * multiplier

# %%
multiply.forall(len(pageviews))(pageviews['requests'], pageviews['mul_requests'], 10.0)

# %%
print(pageviews.head())

# %% [markdown]
# ## 滚动窗口
#
# 在 cuDF 中还支持在滚动窗口上应用内核。这实际上是一个一维模板，可以让我们基于相邻元素执行操作。
#
# ![](images/rolling-windows.png)

# %%
def neigborhood_mean(window):
    c = 0
    for val in window:
        c += val
    return c / len(window)

# %%
pageviews.requests.rolling(3, 1, True).apply(neigborhood_mean)
